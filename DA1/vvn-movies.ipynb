# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("vvn-movies.csv")

# %%
df.head()
# Out:
#    movieID          name  year        Director  budget  marketing  boxOffice  \
# 0        1       Endgame  2018  Russo Brothers     350      150.0     3000.0
# 1        2  Infinity War  2017  Russo Brothers     250      170.0     2400.0
# 2        3      Iron Man  2008     Jon Favreau     150      100.0      760.0
# 3        4    Iron Man 2  2010     Jon Favreau     151      101.0      861.0
# 4        5    Iron Man 3  2012     Jon Favreau     200      120.0      862.0
#
#    studio   genre  imdb
# 0  Marvel    team   7.6
# 1  Marvel    team   8.1
# 2  Marvel  Sci-fi   8.1
# 3  Marvel  Sci-fi   7.1
# 4  Marvel  Sci-fi   6.8

# %%
df['year'].dtype
# Out:
# dtype('int64')

# %%
df['genre'].dtype
# Out:
# dtype('O')

# %%
df.head(10)
# Out:
#    movieID             name  year         Director  budget  marketing  \
# 0        1          Endgame  2018   Russo Brothers   350.0      150.0
# 1        2     Infinity War  2017   Russo Brothers   250.0      170.0
# 2        3         Iron Man  2008      Jon Favreau   150.0      100.0
# 3        4       Iron Man 2  2010      Jon Favreau   151.0      101.0
# 4        5       Iron Man 3  2012      Jon Favreau   200.0      120.0
# 5        6  Captain America  2011     Joe Johnston   120.0       50.0
# 6        7   Winter Soldier  2014   Russo Brothers   170.0      120.0
# 7        8        Civil War  2016   Russo Brothers   270.0      200.0
# 8        9             Thor  2010  Kenneth Branagh   100.0       80.0
# 9       10       Dark World  2013  Kenneth Branagh   201.0      120.0
#
#   boxOffice  studio               genre  imdb
# 0      3000  Marvel                team   7.6
# 1      2400  Marvel                team   8.1
# 2       760  Marvel              Sci-fi   8.1
# 3       861  Marvel              Sci-fi   7.1
# 4       862  Marvel              Sci-fi   6.8
# 5       640  Marvel              Action   7.1
# 6       940  Marvel  Political Thriller   8.7
# 7      1840  Marvel                team   8.7
# 8       760  Marvel        Mythological   7.6
# 9      1200  Marvel        Mythological   6.4

# %%
df.shape
# Out:
# (20, 10)

# %%
df.tail()
# Out:
#     movieID              name  year               Director  budget  marketing  \
# 26     27.0       Dr. Strange  2014        Scott Derickson   230.0       35.0
# 27     28.0  Dr. Strange: MOM  2022              Sam Raima   270.0       55.0
# 28     29.0          Eternals  2022             Chloe Zhao   240.0       38.0
# 29     30.0         Shang Chi  2022  Destin Daniel Cretton   210.0       45.0
# 30      NaN     Black Panther  2018           Ryan Coogler     NaN        NaN
#
#     boxOffice  studio           genre  imdb  movieId
# 26      780.0  Marvel           Magic   7.0      NaN
# 27     1200.0  Marvel           Magic   6.6      NaN
# 28      834.0  Marvel  History Action   7.0      NaN
# 29     1005.0  Marvel         Fantasy   7.8      NaN
# 30        NaN     NaN             NaN   8.1     31.0

# %%
df=df.append({'movieID':30,'name':'Black Panther','year':2018,'Director':'Ryan Coogler','imdb':8.1},ignore_index=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14444\1812350527.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append({'movieID':30,'name':'Black Panther','year':2018,'Director':'Ryan Coogler','imdb':8.1},ignore_index=True)

# %%
df.tail()
# Out:
#     movieID              name  year               Director  budget  marketing  \
# 26     27.0       Dr. Strange  2014        Scott Derickson   230.0       35.0
# 27     28.0  Dr. Strange: MOM  2022              Sam Raima   270.0       55.0
# 28     29.0          Eternals  2022             Chloe Zhao   240.0       38.0
# 29     30.0         Shang Chi  2022  Destin Daniel Cretton   210.0       45.0
# 30     30.0     Black Panther  2018           Ryan Coogler     NaN        NaN
#
#     boxOffice  studio           genre  imdb  Country
# 26      780.0  Marvel           Magic   7.0  America
# 27     1200.0  Marvel           Magic   6.6  America
# 28      834.0  Marvel  History Action   7.0  America
# 29     1005.0  Marvel         Fantasy   7.8  America
# 30        NaN     NaN             NaN   8.1  America

# %%
df.head()
# Out:
#    movieID          name  year        Director  budget  marketing  boxOffice  \
# 0      1.0       Endgame  2018  Russo Brothers   350.0      150.0     3000.0
# 1      2.0  Infinity War  2017  Russo Brothers   250.0      170.0     2400.0
# 2      3.0      Iron Man  2008     Jon Favreau   150.0      100.0      760.0
# 3      4.0    Iron Man 2  2010     Jon Favreau   151.0      101.0      861.0
# 4      5.0    Iron Man 3  2012     Jon Favreau   200.0      120.0      862.0
#
#    studio   genre  imdb  Country
# 0  Marvel    team   7.6  America
# 1  Marvel    team   8.1  America
# 2  Marvel  Sci-fi   8.1  America
# 3  Marvel  Sci-fi   7.1  America
# 4  Marvel  Sci-fi   6.8  America

# %%
df.insert(10,"Country","America")

# %%
print(df)
# Out:
#     movieID              name  year         Director  budget  marketing  \
# 0       1.0           Endgame  2018   Russo Brothers   350.0      150.0
# 1       2.0      Infinity War  2017   Russo Brothers   250.0      170.0
# 2       3.0          Iron Man  2008      Jon Favreau   150.0      100.0
# 3       4.0        Iron Man 2  2010      Jon Favreau   151.0      101.0
# 4       5.0        Iron Man 3  2012      Jon Favreau   200.0      120.0
# 5       6.0   Captain America  2011     Joe Johnston   120.0       50.0
# 6       7.0    Winter Soldier  2014   Russo Brothers   170.0      120.0
# 7       8.0         Civil War  2016   Russo Brothers   270.0      200.0
# 8       9.0              Thor  2010  Kenneth Branagh   100.0       80.0
# 9      10.0        Dark World  2013  Kenneth Branagh   201.0      120.0
# 10     11.0          Ragnarok  2018     Taika Wititi   180.0      121.0
# 11     12.0  Love and thunder  2022     Taika Wititi   181.0      122.0
# 12     13.0        Homecoming  2017        Jon Watts   220.0      100.0
# 13     14.0     Far from home  2019        Jon Watts   240.0      120.0
# 14     15.0       No way home  2021        Jon Watts   260.0      140.0
# 15     16.0             Venom  2018              NaN   170.0      -23.0
# 16     17.0             X-men  2000    Simon Kinberg    94.0        NaN
# 17     18.0          Deadpool  2016       Tim Miller   120.0       70.0
# 18     19.0        Deadpool 2  2019       Tim Miller   200.0       71.0
# 19     20.0        Woolverine  2004    James Mangold     NaN        NaN
# 20      NaN     Black Panther  2018     Ryan Coogler     NaN        NaN
#
#    boxOffice  studio               genre  imdb  Country  movieId
# 0       3000  Marvel                team   7.6  America      NaN
# 1       2400  Marvel                team   8.1  America      NaN
# 2        760  Marvel              Sci-fi   8.1  America      NaN
# 3        861  Marvel              Sci-fi   7.1  America      NaN
# 4        862  Marvel              Sci-fi   6.8  America      NaN
# 5        640  Marvel              Action   7.1  America      NaN
# 6        940  Marvel  Political Thriller   8.7  America      NaN
# 7       1840  Marvel                team   8.7  America      NaN
# 8        760  Marvel        Mythological   7.6  America      NaN
# 9       1200  Marvel        Mythological   6.4  America      NaN
# 10       976  Marvel        Mythological   7.9  America      NaN
# 11      1077  Marvel        Mythological   6.2  America      NaN
# 12       970    Sony         Teen comedy   7.6  America      NaN
# 13      1120    Sony         Teen comedy   7.4  America      NaN
# 14      2170    Sony         Teen comedy   7.9  America      NaN
# 15         H    Sony               Alien   6.9  America      NaN
# 16       560     Fox                team   7.1  America      NaN
# 17       720     Fox        Adult comedy   7.9  America      NaN
# 18      1024     Fox        Adult comedy   7.2  America      NaN
# 19       640     Fox       Action origin  11.0  America      NaN
# 20       NaN     NaN                 NaN   8.1  America     21.0

# %%
df.drop('movieID', inplace=True, axis=1)

# %%
df.drop(29, axis=0, inplace=True)

# %%
df.head()
# Out:
#            name  year        Director  budget  marketing  boxOffice  studio  \
# 0       Endgame  2018  Russo Brothers   350.0      150.0     3000.0  Marvel
# 1  Infinity War  2017  Russo Brothers   250.0      170.0     2400.0  Marvel
# 2      Iron Man  2008     Jon Favreau   150.0      100.0      760.0  Marvel
# 3    Iron Man 2  2010     Jon Favreau   151.0      101.0      861.0  Marvel
# 4    Iron Man 3  2012     Jon Favreau   200.0      120.0      862.0  Marvel
#
#     genre  imdb  Country
# 0    team   7.6  America
# 1    team   8.1  America
# 2  Sci-fi   8.1  America
# 3  Sci-fi   7.1  America
# 4  Sci-fi   6.8  America

# %%
df.at[17,'Country']="Canada"

# %%
df[15:20]
# Out:
#           name  year       Director  budget  marketing  boxOffice studio  \
# 15       Venom  2018            NaN   170.0      -23.0        NaN   Sony
# 16       X-men  2000  Simon Kinberg    94.0        NaN      560.0    Fox
# 17    Deadpool  2016     Tim Miller   120.0       70.0      720.0    Fox
# 18  Deadpool 2  2019     Tim Miller   200.0       71.0     1024.0    Fox
# 19  Woolverine  2004  James Mangold   140.0        NaN      640.0    Fox
#
#             genre  imdb Country
# 15          Alien   6.9     USA
# 16           team   7.1     USA
# 17   Adult comedy   7.9  Canada
# 18   Adult comedy   7.2     USA
# 19  Action origin  11.0     USA

# %%
df.tail()
# Out:
#                 name  year               Director  budget  marketing  \
# 26       Dr. Strange  2014        Scott Derickson   230.0       35.0
# 27  Dr. Strange: MOM  2022              Sam Raima   270.0       55.0
# 28          Eternals  2022             Chloe Zhao   240.0       38.0
# 29         Shang Chi  2022  Destin Daniel Cretton   210.0       45.0
# 30     Black Panther  2018           Ryan Coogler     NaN        NaN
#
#     boxOffice  studio           genre  imdb Country
# 26      780.0  Marvel           Magic   7.0     USA
# 27     1200.0  Marvel           Magic   6.6     USA
# 28      834.0  Marvel  History Action   7.0     USA
# 29     1005.0  Marvel         Fantasy   7.8     USA
# 30        NaN     NaN             NaN   8.1     USA

# %%
df.replace("America", "USA", inplace=True)

# %%
display(df)
# Out:
#     movieID              name  year         Director  budget  marketing  \
# 0       1.0           Endgame  2018   Russo Brothers   350.0      150.0
# 1       2.0      Infinity War  2017   Russo Brothers   250.0      170.0
# 2       3.0          Iron Man  2008      Jon Favreau   150.0      100.0
# 3       4.0        Iron Man 2  2010      Jon Favreau   151.0      101.0
# 4       5.0        Iron Man 3  2012      Jon Favreau   200.0      120.0
# 5       6.0   Captain America  2011     Joe Johnston   120.0       50.0
# 6       7.0    Winter Soldier  2014   Russo Brothers   170.0      120.0
# 7       8.0         Civil War  2016   Russo Brothers   270.0      200.0
# 8       9.0              Thor  2010  Kenneth Branagh   100.0       80.0
# 9      10.0        Dark World  2013  Kenneth Branagh   201.0      120.0
# 10     11.0          Ragnarok  2018     Taika Wititi   180.0      121.0
# 11     12.0  Love and thunder  2022     Taika Wititi   181.0      122.0
# 12     13.0        Homecoming  2017        Jon Watts   220.0      100.0
# 13     14.0     Far from home  2019        Jon Watts   240.0      120.0
# 14     15.0       No way home  2021        Jon Watts   260.0      140.0
# 15     16.0             Venom  2018              NaN   170.0      -23.0
# 16     17.0             X-men  2000    Simon Kinberg    94.0        NaN
# 17     18.0          Deadpool  2016       Tim Miller   120.0       70.0
# 18     19.0        Deadpool 2  2019       Tim Miller   200.0       71.0
# 19     20.0        Woolverine  2004    James Mangold     NaN        NaN
# 20      NaN     Black Panther  2018     Ryan Coogler     NaN        NaN
#
#    boxOffice  studio               genre  imdb Country
# 0       3000  Marvel                team   7.6     USA
# 1       2400  Marvel                team   8.1     USA
# 2        760  Marvel              Sci-fi   8.1     USA
# 3        861  Marvel              Sci-fi   7.1     USA
# 4        862  Marvel              Sci-fi   6.8     USA
# 5        640  Marvel              Action   7.1     USA
# 6        940  Marvel  Political Thriller   8.7     USA
# 7       1840  Marvel                team   8.7     USA
# 8        760  Marvel        Mythological   7.6     USA
# 9       1200  Marvel        Mythological   6.4     USA
# 10       976  Marvel        Mythological   7.9     USA
# 11      1077  Marvel        Mythological   6.2     USA
# 12       970    Sony         Teen comedy   7.6     USA
# 13      1120    Sony         Teen comedy   7.4     USA
# 14      2170    Sony         Teen comedy   7.9     USA
# 15         H    Sony               Alien   6.9     USA
# 16       560     Fox                team   7.1     USA
# 17       720     Fox        Adult comedy   7.9     USA
# 18      1024     Fox        Adult comedy   7.2     USA
# 19       640     Fox       Action origin  11.0     USA
# 20       NaN     NaN    Political action   8.1     USA

# %%
df.mean(numeric_only=True)
# Out:
# movieID        10.500000
# year         2014.333333
# budget        190.894737
# marketing     107.333333
# imdb            7.685714
# dtype: float64

# %%
df.sum(numeric_only=True)
# Out:
# movieID        210.0
# year         42301.0
# budget        3627.0
# marketing     1932.0
# imdb           161.4
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# movieID        10.5
# year         2016.0
# budget        181.0
# marketing     120.0
# imdb            7.6
# dtype: float64

# %%
df.mode()
# Out:
#                  name    year        Director  budget  marketing  boxOffice  \
# 0   A&W: QuantamMania  2018.0  Russo Brothers   200.0  89.038462      945.0
# 1              Antman  2022.0             NaN     NaN        NaN        NaN
# 2     Antman and Wasp     NaN             NaN     NaN        NaN        NaN
# 3       Black Panther     NaN             NaN     NaN        NaN        NaN
# 4     Captain America     NaN             NaN     NaN        NaN        NaN
# 5           Civil War     NaN             NaN     NaN        NaN        NaN
# 6          Dark World     NaN             NaN     NaN        NaN        NaN
# 7            Deadpool     NaN             NaN     NaN        NaN        NaN
# 8          Deadpool 2     NaN             NaN     NaN        NaN        NaN
# 9         Dr. Strange     NaN             NaN     NaN        NaN        NaN
# 10   Dr. Strange: MOM     NaN             NaN     NaN        NaN        NaN
# 11            Endgame     NaN             NaN     NaN        NaN        NaN
# 12           Eternals     NaN             NaN     NaN        NaN        NaN
# 13      Far from home     NaN             NaN     NaN        NaN        NaN
# 14               GOTG     NaN             NaN     NaN        NaN        NaN
# 15        GOTG Vol. 2     NaN             NaN     NaN        NaN        NaN
# 16        GOTG Vol. 3     NaN             NaN     NaN        NaN        NaN
# 17         Homecoming     NaN             NaN     NaN        NaN        NaN
# 18       Infinity War     NaN             NaN     NaN        NaN        NaN
# 19           Iron Man     NaN             NaN     NaN        NaN        NaN
# 20         Iron Man 2     NaN             NaN     NaN        NaN        NaN
# 21         Iron Man 3     NaN             NaN     NaN        NaN        NaN
# 22   Love and thunder     NaN             NaN     NaN        NaN        NaN
# 23        No way home     NaN             NaN     NaN        NaN        NaN
# 24           Ragnarok     NaN             NaN     NaN        NaN        NaN
# 25          Shang Chi     NaN             NaN     NaN        NaN        NaN
# 26               Thor     NaN             NaN     NaN        NaN        NaN
# 27              Venom     NaN             NaN     NaN        NaN        NaN
# 28     Winter Soldier     NaN             NaN     NaN        NaN        NaN
# 29         Woolverine     NaN             NaN     NaN        NaN        NaN
# 30              X-men     NaN             NaN     NaN        NaN        NaN
#
#     studio         genre  imdb Country
# 0   Marvel  Mythological   7.1     USA
# 1      NaN          team   NaN     NaN
# 2      NaN           NaN   NaN     NaN
# 3      NaN           NaN   NaN     NaN
# 4      NaN           NaN   NaN     NaN
# 5      NaN           NaN   NaN     NaN
# 6      NaN           NaN   NaN     NaN
# 7      NaN           NaN   NaN     NaN
# 8      NaN           NaN   NaN     NaN
# 9      NaN           NaN   NaN     NaN
# 10     NaN           NaN   NaN     NaN
# 11     NaN           NaN   NaN     NaN
# 12     NaN           NaN   NaN     NaN
# 13     NaN           NaN   NaN     NaN
# 14     NaN           NaN   NaN     NaN
# 15     NaN           NaN   NaN     NaN
# 16     NaN           NaN   NaN     NaN
# 17     NaN           NaN   NaN     NaN
# 18     NaN           NaN   NaN     NaN
# 19     NaN           NaN   NaN     NaN
# 20     NaN           NaN   NaN     NaN
# 21     NaN           NaN   NaN     NaN
# 22     NaN           NaN   NaN     NaN
# 23     NaN           NaN   NaN     NaN
# 24     NaN           NaN   NaN     NaN
# 25     NaN           NaN   NaN     NaN
# 26     NaN           NaN   NaN     NaN
# 27     NaN           NaN   NaN     NaN
# 28     NaN           NaN   NaN     NaN
# 29     NaN           NaN   NaN     NaN
# 30     NaN           NaN   NaN     NaN

# %%
df.isna().sum()
# Out:
# name         0
# year         0
# Director     1
# budget       1
# marketing    5
# boxOffice    4
# studio       1
# genre        1
# imdb         2
# Country      0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 15

# %%
mean_value=df['marketing'].mean()
df['marketing'].fillna(value=mean_value, inplace=True)
median_value=df['boxOffice'].median()
df['boxOffice'].fillna(value=median_value, inplace=True)
mode_value=df['imdb'].mode()
df['imdb'].fillna(value=float(mode_value), inplace=True)
print(df)
# Out:
#     movieID               name  year               Director  budget  \
# 0         1            Endgame  2018         Russo Brothers     350
# 1         2       Infinity War  2017         Russo Brothers     250
# 2         3           Iron Man  2008            Jon Favreau     150
# 3         4         Iron Man 2  2010            Jon Favreau     151
# 4         5         Iron Man 3  2012            Jon Favreau     200
# 5         6    Captain America  2011           Joe Johnston     120
# 6         7     Winter Soldier  2014         Russo Brothers     170
# 7         8          Civil War  2016         Russo Brothers     270
# 8         9               Thor  2010        Kenneth Branagh     100
# 9        10         Dark World  2013        Kenneth Branagh     201
# 10       11           Ragnarok  2018           Taika Wititi     180
# 11       12   Love and thunder  2022           Taika Wititi     181
# 12       13         Homecoming  2017              Jon Watts     220
# 13       14      Far from home  2019              Jon Watts     240
# 14       15        No way home  2021              Jon Watts     260
# 15       16              Venom  2018                    NaN     170
# 16       17              X-men  2000          Simon Kinberg      94
# 17       18           Deadpool  2016             Tim Miller     120
# 18       19         Deadpool 2  2019             Tim Miller     200
# 19       20         Woolverine  2004          James Mangold     140
# 20       21               GOTG  2014             James Gunn     200
# 21       22        GOTG Vol. 2  2017             James Gunn     250
# 22       23        GOTG Vol. 3  2023             James Gunn     270
# 23       24             Antman  2015            Peyton Reed     180
# 24       25    Antman and Wasp  2019            Peyton Reed     200
# 25       26  A&W: QuantamMania  2023            Peyton Reed     250
# 26       27        Dr. Strange  2014        Scott Derickson     230
# 27       28   Dr. Strange: MOM  2022              Sam Raima     270
# 28       29           Eternals  2022             Chloe Zhao     240
# 29       30          Shang Chi  2022  Destin Daniel Cretton     210
#
#      marketing  boxOffice  studio               genre   score  imdb
# 0   150.000000     3000.0  Marvel                team  rotten   7.6
# 1   170.000000     2400.0  Marvel                team   fresh   8.1
# 2   100.000000      760.0  Marvel              Sci-fi   fresh   8.1
# 3   101.000000      861.0  Marvel              Sci-fi  rotten   7.1
# 4   120.000000      862.0  Marvel              Sci-fi  rotten   6.8
# 5    50.000000      640.0  Marvel              Action  rotten   7.1
# 6   120.000000      940.0  Marvel  Political Thriller   fresh   8.7
# 7   200.000000     1840.0  Marvel                team   fresh   8.7
# 8    80.000000      760.0  Marvel        Mythological  rotten   7.6
# 9   120.000000     1200.0  Marvel        Mythological  rotten   6.4
# 10  121.000000      976.0  Marvel        Mythological  rotten   7.9
# 11  122.000000     1077.0  Marvel        Mythological  rotten   6.2
# 12  100.000000      970.0    Sony         Teen comedy  rotten   7.6
# 13  120.000000     1120.0    Sony         Teen comedy  rotten   7.4
# 14  140.000000     2170.0    Sony         Teen comedy  rotten   7.9
# 15  -23.000000      945.0    Sony               Alien  rotten   6.9
# 16   89.038462      560.0     Fox                team  rotten   7.1
# 17   70.000000      720.0     Fox        Adult comedy  rotten   7.9
# 18   71.000000     1024.0     Fox        Adult comedy  rotten   7.2
# 19   89.038462      640.0     Fox       Action origin   fresh  11.0
# 20   40.000000      870.0  Marvel        Space Comedy  rotten   7.8
# 21   60.000000      990.0  Marvel        Space Comedy  rotten   7.2
# 22   89.038462      945.0  Marvel        Space Comedy  rotten   7.1
# 23   50.000000      870.0  Marvel       Action Comedy  rotten   7.1
# 24   60.000000      945.0  Marvel       Action Comedy  rotten   7.0
# 25   89.038462      945.0  Marvel       Action Comedy  rotten   7.1
# 26   35.000000      780.0  Marvel               Magic  rotten   7.0
# 27   55.000000     1200.0  Marvel               Magic  rotten   6.6
# 28   38.000000      834.0  Marvel      History Action  rotten   7.0
# 29   45.000000     1005.0  Marvel             Fantasy  rotten   7.8

# %%
df['studio'].fillna(value="Marvel", inplace=True)

# %%
df['studio'].replace(['Marvel', 'Fox', 'Sony'],
                        [0,1,2], inplace=True)

# %%
df['Country'].replace([0,1], ['USA', 'Canada'], inplace=True)

# %%
values=['fresh','rotten']
conditions=[(df["imdb"]>8),(df["imdb"]<=8)]
arr=np.select(conditions,values)
print(arr)
df.insert(9,"score",arr)
# Out:
# ['rotten' 'fresh' 'fresh' 'rotten' 'rotten' 'rotten' 'fresh' 'fresh'
#  'rotten' 'rotten' 'rotten' 'rotten' 'rotten' 'rotten' 'rotten' 'rotten'
#  'rotten' 'rotten' 'rotten' 'fresh' 'rotten' 'rotten' 'rotten' 'rotten'
#  'rotten' 'rotten' 'rotten' 'rotten' 'rotten' 'rotten']

# %%
import matplotlib.pyplot as plt
df["budget"].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
from pandas import DataFrame
from sklearn.preprocessing import MinMaxScaler


trans = MinMaxScaler()
data = trans.fit_transform(df[:,4:7])
# convert the array back to a dataframe
dataset = DataFrame(data)
# summarize
print(dataset.describe())
# histograms of the variables
dataset.hist()
plt.show()

# %%
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import MinMaxScaler

# %%
df_min_max_scaled = df[['imdb','boxOffice','marketing','budget']]
  

for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  
print(df_min_max_scaled)
# Out:
#         imdb  boxOffice  marketing    budget
# 0   0.291667   1.000000   0.775785  1.000000
# 1   0.395833   0.754098   0.865471  0.609375
# 2   0.395833   0.081967   0.551570  0.218750
# 3   0.187500   0.123361   0.556054  0.222656
# 4   0.125000   0.123770   0.641256  0.414062
# 5   0.187500   0.032787   0.327354  0.101562
# 6   0.520833   0.155738   0.641256  0.296875
# 7   0.520833   0.524590   1.000000  0.687500
# 8   0.291667   0.081967   0.461883  0.023438
# 9   0.041667   0.262295   0.641256  0.417969
# 10  0.354167   0.170492   0.645740  0.335938
# 11  0.000000   0.211885   0.650224  0.339844
# 12  0.291667   0.168033   0.551570  0.492188
# 13  0.250000   0.229508   0.641256  0.570312
# 14  0.354167   0.659836   0.730942  0.648438
# 15  0.145833   0.157787   0.000000  0.296875
# 16  0.187500   0.000000   0.502415  0.000000
# 17  0.354167   0.065574   0.417040  0.101562
# 18  0.208333   0.190164   0.421525  0.414062
# 19  1.000000   0.032787   0.502415  0.179688
# 20  0.333333   0.127049   0.282511  0.414062
# 21  0.208333   0.176230   0.372197  0.609375
# 22  0.187500   0.157787   0.502415  0.687500
# 23  0.187500   0.127049   0.327354  0.335938
# 24  0.166667   0.157787   0.372197  0.414062
# 25  0.187500   0.157787   0.502415  0.609375
# 26  0.166667   0.090164   0.260090  0.531250
# 27  0.083333   0.262295   0.349776  0.687500
# 28  0.166667   0.112295   0.273543  0.570312
# 29  0.333333   0.182377   0.304933  0.453125
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14444\3486390234.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())

# %%
import matplotlib.pyplot as plt
df_min_max_scaled["budget"].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_min_max_scaled = df[['imdb','boxOffice','marketing','budget']]
print(df_min_max_scaled)
# Out:
#     imdb  boxOffice   marketing  budget
# 0    7.6     3000.0  150.000000     350
# 1    8.1     2400.0  170.000000     250
# 2    8.1      760.0  100.000000     150
# 3    7.1      861.0  101.000000     151
# 4    6.8      862.0  120.000000     200
# 5    7.1      640.0   50.000000     120
# 6    8.7      940.0  120.000000     170
# 7    8.7     1840.0  200.000000     270
# 8    7.6      760.0   80.000000     100
# 9    6.4     1200.0  120.000000     201
# 10   7.9      976.0  121.000000     180
# 11   6.2     1077.0  122.000000     181
# 12   7.6      970.0  100.000000     220
# 13   7.4     1120.0  120.000000     240
# 14   7.9     2170.0  140.000000     260
# 15   6.9      945.0  -23.000000     170
# 16   7.1      560.0   89.038462      94
# 17   7.9      720.0   70.000000     120
# 18   7.2     1024.0   71.000000     200
# 19  11.0      640.0   89.038462     140
# 20   7.8      870.0   40.000000     200
# 21   7.2      990.0   60.000000     250
# 22   7.1      945.0   89.038462     270
# 23   7.1      870.0   50.000000     180
# 24   7.0      945.0   60.000000     200
# 25   7.1      945.0   89.038462     250
# 26   7.0      780.0   35.000000     230
# 27   6.6     1200.0   55.000000     270
# 28   7.0      834.0   38.000000     240
# 29   7.8     1005.0   45.000000     210

# %%
df.describe()
# Out:
#          movieID         year      budget   marketing    boxOffice       imdb
# count  30.000000    30.000000   30.000000   30.000000    30.000000  30.000000
# mean   15.500000  2015.800000  202.233333   89.038462  1094.966667   7.500000
# std     8.803408     5.591866   58.205749   45.709337   546.987580   0.890564
# min     1.000000  2000.000000   94.000000  -23.000000   560.000000   6.200000
# 25%     8.250000  2013.250000  170.000000   56.250000   840.750000   7.025000
# 50%    15.500000  2017.000000  200.000000   89.038462   945.000000   7.200000
# 75%    22.750000  2019.000000  247.500000  120.000000  1063.750000   7.875000
# max    30.000000  2023.000000  350.000000  200.000000  3000.000000  11.000000

# %%
df_standard_scaled = df[['imdb','boxOffice','marketing','budget']]
  

for column in df_standard_scaled.columns:
    df_standard_scaled[column] = (df_standard_scaled[column] - df_standard_scaled[column].mean()) / (df_standard_scaled[column].max() - df_standard_scaled[column].min())    
  
print(df_standard_scaled)
